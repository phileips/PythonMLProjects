# %% [markdown]
# # pandas

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.arange(20).reshape(5,4),index=['R1','R2','R3','R4','R5'],columns=['C1','C2','C3','C4'])

# %%
df
# Out:
#     C1  C2  C3  C4
# R1   0   1   2   3
# R2   4   5   6   7
# R3   8   9  10  11
# R4  12  13  14  15
# R5  16  17  18  19

# %%
(df.loc[['R1','R3']])
# Out:
#     C1  C2  C3  C4
# R1   0   1   2   3
# R3   8   9  10  11

# %%
df.to_csv('Test1.csv')

# %%
df.loc['R2'].value_counts()
# Out:
# 7    1
# 6    1
# 5    1
# 4    1
# Name: R2, dtype: int64

# %%
df.isnull().sum()
# Out:
# C1    0
# C2    0
# C3    0
# C4    0
# dtype: int64

# %%
df.loc['R2'].unique()
# Out:
# array([4, 5, 6, 7], dtype=int64)

# %%
data=pd.read_csv('Test1.csv')

# %%
data.describe()
# Out:
#               C1         C2         C3         C4
# count   5.000000   5.000000   5.000000   5.000000
# mean    8.000000   9.000000  10.000000  11.000000
# std     6.324555   6.324555   6.324555   6.324555
# min     0.000000   1.000000   2.000000   3.000000
# 25%     4.000000   5.000000   6.000000   7.000000
# 50%     8.000000   9.000000  10.000000  11.000000
# 75%    12.000000  13.000000  14.000000  15.000000
# max    16.000000  17.000000  18.000000  19.000000

# %%
data.head()
# Out:
#   Unnamed: 0  C1  C2  C3  C4
# 0         R1   0   1   2   3
# 1         R2   4   5   6   7
# 2         R3   8   9  10  11
# 3         R4  12  13  14  15
# 4         R5  16  17  18  19

# %%
dataSemiColon=pd.read_csv('Test11.csv',sep=';',usecols=['C1','C2','C3'],index_col=False)
dataSemiColon
# Out:
#    C1  C2  C3
# 0   0   1   2
# 1   4   5   6
# 2   8   9  10
# 3  12  13  14
# 4  16  17  18

# %%
dataSemiColon['C1'].value_counts()
# Out:
# 12    1
# 4     1
# 16    1
# 8     1
# 0     1
# Name: C1, dtype: int64

# %%
df=dataSemiColon
df['C2']>5
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: C2, dtype: bool

# %%
#JSON

df=pd.read_json('{"data":{"id":3,"name":"true red","year":2002,"color":"#BF1932","pantone_value":"19-1664"},"support":{"url":"https://reqres.in/#support-heading","text":"To keep ReqRes free, contributions towards server costs are appreciated!"}}')

# %%
df
# Out:
#                    data                                            support
# id                    3                                                NaN
# name           true red                                                NaN
# year               2002                                                NaN
# color           #BF1932                                                NaN
# pantone_value   19-1664                                                NaN
# url                 NaN                 https://reqres.in/#support-heading
# text                NaN  To keep ReqRes free, contributions towards ser...

# %%
df.to_csv('test2.csv')

# %%
_url='https://en.wikipedia.org/wiki/2014_Indian_general_election'
df_wtc=pd.read_html(_url,match='State/UT-wise')
df_wtc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-535dc8383868> in <module>
#       1 _url='https://en.wikipedia.org/wiki/2014_Indian_general_election'
# ----> 2 df_wtc=pd.read_html(_url,match='State/UT-wise')
#       3 df_wtc
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
# ...

# %%
df_wtc
# Out:
# [                                                    0  \
#  0                                                 NaN
#  1                          ← 2009 7 April 2014 2019 →
#  2                                              ← 2009
#  3                         ← outgoing membersmembers →
#  4   all 543 seats in the Lok Sabha272 seats needed...
#  5                                       Opinion polls
#  6                                             Turnout
#  7   Leader Narendra Modi Sonia Gandhi J. Jayalalit...
#  8                                                 NaN
#  9                                              Leader
#  10                                              Party
#  11                                           Alliance
#  12                                       Leader since
#  13                                      Leader's seat
#  14                                      Last election
#  15                                          Seats won
# ...
